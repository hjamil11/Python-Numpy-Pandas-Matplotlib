# %% [markdown]
# * **Author:** Hamad Ahmed
#     * This program reads a csv file called 'movies.csv' into a pandas dataframe. Then, it creates two figures. Figure one contains two plots. One of the plot is a normalized histogram of the movie ratings. The other plot is a line of the normal distribution using the mean and standard deviation of the movie ratings. Figure two involves a horizontal bar chart of the top 10 movies based on number of votes with the most votes being on the top of the chart.
# - _Major_: CS
# - **Creation Date**: 03/11
# - Due Date: 4/22
# - Course: CSC223
# - Professor Name: Earl
# - Assignment: Homework 5
# - Filename: main.ipynb

# %%
# %matplotlib inline

# STUDENT TODO: Write statements to import numpy, pandas, & matplotlib.pyplot
# following conventions. 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# STUDENT: Do not modify the code in this cell. 

def norm_dist(x, mean, std):
    '''
        Use this function to calculate a normal distribution
        
        Parameters:
            x - 1D Array of Distribution
            mean - The mean of the dataset
            std - The standard deviation of the dataset
            
        Return:
            A numpy array
    '''
    from scipy.stats import norm
    return norm.pdf(x, mean, std)
    

# Import the dataset
movies = pd.read_csv('https://faculty.kutztown.edu/earl/teaching/2021-2022/223-adv-sci-program/hw/materials/movies.csv', index_col=0)
movies.head()
# Out:
#                       title  year  length  budget  rating  votes    r1    r2  \
# 1                         $  1971     121     NaN     6.4    348   4.5   4.5
# 2         $1000 a Touchdown  1939      71     NaN     6.0     20   0.0  14.5
# 3    $21 a Day Once a Month  1941       7     NaN     8.2      5   0.0   0.0
# 4                   $40,000  1996      70     NaN     8.2      6  14.5   0.0
# 5  $50,000 Climax Show, The  1975      71     NaN     3.4     17  24.5   4.5
#
#     r3    r4  ...    r9   r10  mpaa  Action  Animation  Comedy Drama  \
# 1  4.5   4.5  ...   4.5   4.5   NaN       0          0       1     1
# 2  4.5  24.5  ...   4.5  14.5   NaN       0          0       1     0
# 3  0.0   0.0  ...  24.5  24.5   NaN       0          1       0     0
# 4  0.0   0.0  ...  34.5  45.5   NaN       0          0       1     0
# 5  0.0  14.5  ...   0.0  24.5   NaN       0          0       0     0
#
#    Documentary  Romance  Short
# 1            0        0      0
# ...

# %%
# STUDENT TODO: Code for Figure 1
plt.hist(movies['rating'], bins = 10, density = True, label = "Movie Ratings")

x = np.linspace(movies['rating'].min(), movies['rating'].max(), 100)

mean = movies['rating'].mean()

std_dev = movies['rating'].std()

plt.plot(x, norm_dist(x, mean, std_dev), label = "Norm. Dist. Ratings")

plt.xlabel("Rating")

plt.ylabel("Distribution")

plt.title("Movie Rating")

plt.legend()

plt.show()

# %%
# STUDENT TODO: Code for Figure 2
# sorted_votes = movies['votes'].sort_values(ascending = False)
# x = movies[movies['votes'].nlargest(n = 10)]['title']
# y = df.nlargest(n = 10, columns = ['votes'])

# df = movies.sort_values(by = 'votes', ascending = False)
df = movies.sort_values(by = 'votes', ascending = True)

# x = df['title'].head(10)
x = df['title'].tail(10)
# y = df['votes'].head(10)
y = df['votes'].tail(10)

plt.barh(x, y)

plt.xlabel("Votes")
plt.ylabel("Movie Title")

plt.title("10 Highest Voted Movies")

plt.show()

# print(sorted_votes.head(10))
